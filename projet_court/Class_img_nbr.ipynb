# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
import sklearn.metrics
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### Importation et affichage des images

# %%
train_images = np.load("train_images.npy")
train_labels = np.load("train_labels.npy")
test_images = np.load("test_images.npy")
test_labels = np.load("test_labels.npy")

# %%
plt.figure(figsize=[10,10])
for i in range (10):    # for first 25 images
  plt.subplot(5, 5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(train_labels[i])

plt.show()

# %%
class_counts = pd.Series(train_labels).value_counts()

# Create a bar graph using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(class_counts.index, class_counts.values, color='skyblue')
plt.xlabel('Classes')
plt.ylabel('Number of Instances')
plt.title('Number of Instances per Class')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Apprentissage en couche dense

# %% [markdown]
# #### Création des vecteurs de pixel des images

# %%
train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

num_pixels = train_images.shape[1] * train_images.shape[2] #784
train_images_flat = train_images.reshape(train_images.shape[0], num_pixels)
test_images_flat = test_images.reshape(test_images.shape[0], num_pixels)
print(train_images_flat.shape)
print(test_images_flat.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# #### Transformation des labels en format one hot

# %%
num_classes = 10
train_labels_oh = keras.utils.to_categorical(train_labels, num_classes)
test_labels_oh = keras.utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# #### Mélange des données d'entrainement

# %%
ns =  train_images.shape[0] #number of examples
np.random.seed()
shuffle_index = np.random.permutation(ns)
train_images_flat, train_labels_oh = train_images_flat[shuffle_index,:], train_labels_oh[shuffle_index,]

# %% [markdown]
# #### Création du model

# %%
optimizer = RMSprop(learning_rate=0.003)
callback = EarlyStopping(monitor="val_accuracy", patience = 5, restore_best_weights = True)

# %%
model = Sequential()
model.add(Dense(256, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
model.add(Dropout(.3))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(.3))
model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_94 (Dense)            (None, 256)               200960
#
#  dropout_73 (Dropout)        (None, 256)               0
#
#  dense_95 (Dense)            (None, 128)               32896
#
#  dropout_74 (Dropout)        (None, 128)               0
#
#  dense_96 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Apprentissage

# %%
history = model.fit(train_images_flat, train_labels_oh, validation_split=0.2, epochs=30, batch_size=128, callback = [callback])
#
scores = model.evaluate(test_images_flat, test_labels_oh)
print("Neural network accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/30
# 375/375 [==============================] - 5s 9ms/step - loss: 2.0288 - accuracy: 0.2775 - val_loss: 1.6897 - val_accuracy: 0.4387
# Epoch 2/30
# 375/375 [==============================] - 2s 7ms/step - loss: 1.6089 - accuracy: 0.4507 - val_loss: 1.3628 - val_accuracy: 0.5698
# Epoch 3/30
# 375/375 [==============================] - 3s 7ms/step - loss: 1.3929 - accuracy: 0.5284 - val_loss: 1.2013 - val_accuracy: 0.6087
# Epoch 4/30
# 375/375 [==============================] - 3s 7ms/step - loss: 1.2615 - accuracy: 0.5787 - val_loss: 1.0519 - val_accuracy: 0.6727
# Epoch 5/30
# 375/375 [==============================] - 3s 7ms/step - loss: 1.1730 - accuracy: 0.6080 - val_loss: 0.9590 - val_accuracy: 0.7039
# Epoch 6/30
# 375/375 [==============================] - 2s 7ms/step - loss: 1.1047 - accuracy: 0.6346 - val_loss: 0.9136 - val_accuracy: 0.7166
# Epoch 7/30
# 375/375 [==============================] - 3s 7ms/step - loss: 1.0492 - accuracy: 0.6553 - val_loss: 0.8748 - val_accuracy: 0.7337
# Epoch 8/30
# 375/375 [==============================] - 2s 7ms/step - loss: 1.0078 - accuracy: 0.6702 - val_loss: 0.8139 - val_accuracy: 0.7475
# Epoch 9/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.9625 - accuracy: 0.6834 - val_loss: 0.7884 - val_accuracy: 0.7561
# Epoch 10/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.9389 - accuracy: 0.6938 - val_loss: 0.7645 - val_accuracy: 0.7655
# Epoch 11/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.9063 - accuracy: 0.7053 - val_loss: 0.7426 - val_accuracy: 0.7728
# Epoch 12/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.8847 - accuracy: 0.7107 - val_loss: 0.7126 - val_accuracy: 0.7788
# Epoch 13/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.8645 - accuracy: 0.7186 - val_loss: 0.7026 - val_accuracy: 0.7824
# Epoch 14/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.8337 - accuracy: 0.7311 - val_loss: 0.6861 - val_accuracy: 0.7873
# Epoch 15/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.8215 - accuracy: 0.7334 - val_loss: 0.6636 - val_accuracy: 0.7951
# Epoch 16/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.8025 - accuracy: 0.7385 - val_loss: 0.6525 - val_accuracy: 0.7980
# Epoch 17/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.7919 - accuracy: 0.7434 - val_loss: 0.6542 - val_accuracy: 0.7972
# Epoch 18/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.7739 - accuracy: 0.7500 - val_loss: 0.6306 - val_accuracy: 0.8048
# Epoch 19/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.7627 - accuracy: 0.7539 - val_loss: 0.6296 - val_accuracy: 0.8039
# Epoch 20/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.7438 - accuracy: 0.7581 - val_loss: 0.6143 - val_accuracy: 0.8111
# Epoch 21/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.7392 - accuracy: 0.7611 - val_loss: 0.6157 - val_accuracy: 0.8112
# Epoch 22/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.7224 - accuracy: 0.7660 - val_loss: 0.6102 - val_accuracy: 0.8100
# Epoch 23/30
# 375/375 [==============================] - 4s 11ms/step - loss: 0.7131 - accuracy: 0.7699 - val_loss: 0.5956 - val_accuracy: 0.8189
# Epoch 24/30
# 375/375 [==============================] - 3s 8ms/step - loss: 0.7071 - accuracy: 0.7715 - val_loss: 0.5917 - val_accuracy: 0.8177
# Epoch 25/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6926 - accuracy: 0.7765 - val_loss: 0.5885 - val_accuracy: 0.8188
# Epoch 26/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6860 - accuracy: 0.7791 - val_loss: 0.5818 - val_accuracy: 0.8209
# Epoch 27/30
# 375/375 [==============================] - 3s 8ms/step - loss: 0.6786 - accuracy: 0.7813 - val_loss: 0.5782 - val_accuracy: 0.8242
# Epoch 28/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6730 - accuracy: 0.7826 - val_loss: 0.5858 - val_accuracy: 0.8224
# Epoch 29/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6629 - accuracy: 0.7855 - val_loss: 0.5692 - val_accuracy: 0.8265
# Epoch 30/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6509 - accuracy: 0.7909 - val_loss: 0.5649 - val_accuracy: 0.8304
# 313/313 [==============================] - 1s 2ms/step - loss: 80.0309 - accuracy: 0.7977
# Neural network accuracy: 79.77%

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model.predict(test_images_flat)
y_pred_classes = np.argmax(y_pred,axis = 1)
y_pred_classes
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([7, 2, 1, ..., 4, 6, 6])

# %%
sns.heatmap(sklearn.metrics.confusion_matrix(test_labels, y_pred_classes, normalize="true"), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Ajout de couches

# %%
optimizer = RMSprop(learning_rate=0.0005)
model2 = Sequential()
model2.add(Dense(256, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(128, kernel_initializer='normal', activation='relu'))
model2.add(Dropout(.3))
model2.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
model2.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_84 (Dense)            (None, 256)               200960
#
#  dropout_64 (Dropout)        (None, 256)               0
#
#  dense_85 (Dense)            (None, 128)               32896
#
#  dropout_65 (Dropout)        (None, 128)               0
#
#  dense_86 (Dense)            (None, 128)               16512
#
#  dropout_66 (Dropout)        (None, 128)               0
#
#  dense_87 (Dense)            (None, 128)               16512
#
#  dropout_67 (Dropout)        (None, 128)               0
#
#  dense_88 (Dense)            (None, 128)               16512
#
#  dropout_68 (Dropout)        (None, 128)               0
#
#  dense_89 (Dense)            (None, 128)               16512
#
#  dropout_69 (Dropout)        (None, 128)               0
#
#  dense_90 (Dense)            (None, 128)               16512
#
#  dropout_70 (Dropout)        (None, 128)               0
#
#  dense_91 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 317,706
# Trainable params: 317,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model2.fit(train_images_flat, train_labels_oh, validation_split=0.2, epochs=50, batch_size=128, callback = [callback])
#
scores = model2.evaluate(test_images_flat, test_labels_oh)
print("Neural network accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/50
# 375/375 [==============================] - 6s 13ms/step - loss: 2.1527 - accuracy: 0.1947 - val_loss: 2.0675 - val_accuracy: 0.2209
# Epoch 2/50
# 375/375 [==============================] - 5s 12ms/step - loss: 1.9468 - accuracy: 0.2645 - val_loss: 1.8049 - val_accuracy: 0.3055
# Epoch 3/50
# 375/375 [==============================] - 4s 12ms/step - loss: 1.8159 - accuracy: 0.3185 - val_loss: 1.6986 - val_accuracy: 0.3674
# Epoch 4/50
# 375/375 [==============================] - 5s 12ms/step - loss: 1.6828 - accuracy: 0.3894 - val_loss: 1.4574 - val_accuracy: 0.4778
# Epoch 5/50
# 375/375 [==============================] - 5s 14ms/step - loss: 1.5588 - accuracy: 0.4455 - val_loss: 1.3672 - val_accuracy: 0.5213
# Epoch 6/50
# 375/375 [==============================] - 5s 12ms/step - loss: 1.4622 - accuracy: 0.4826 - val_loss: 1.2359 - val_accuracy: 0.5893
# Epoch 7/50
# 375/375 [==============================] - 5s 13ms/step - loss: 1.3814 - accuracy: 0.5187 - val_loss: 1.1511 - val_accuracy: 0.6087
# Epoch 8/50
# 375/375 [==============================] - 6s 17ms/step - loss: 1.3231 - accuracy: 0.5440 - val_loss: 1.1086 - val_accuracy: 0.6297
# Epoch 9/50
# 375/375 [==============================] - 6s 15ms/step - loss: 1.2713 - accuracy: 0.5647 - val_loss: 1.0492 - val_accuracy: 0.6576
# Epoch 10/50
# 375/375 [==============================] - 5s 14ms/step - loss: 1.2266 - accuracy: 0.5866 - val_loss: 0.9836 - val_accuracy: 0.6743
# Epoch 11/50
# 375/375 [==============================] - 7s 19ms/step - loss: 1.1865 - accuracy: 0.6032 - val_loss: 0.9627 - val_accuracy: 0.6849
# Epoch 12/50
# 375/375 [==============================] - 5s 14ms/step - loss: 1.1552 - accuracy: 0.6154 - val_loss: 0.9405 - val_accuracy: 0.6952
# Epoch 13/50
# 375/375 [==============================] - 5s 14ms/step - loss: 1.1188 - accuracy: 0.6315 - val_loss: 0.9158 - val_accuracy: 0.7063
# Epoch 14/50
# 375/375 [==============================] - 5s 12ms/step - loss: 1.0908 - accuracy: 0.6419 - val_loss: 0.8584 - val_accuracy: 0.7222
# Epoch 15/50
# 375/375 [==============================] - 6s 15ms/step - loss: 1.0671 - accuracy: 0.6501 - val_loss: 0.8329 - val_accuracy: 0.7283
# Epoch 16/50
# 375/375 [==============================] - 5s 13ms/step - loss: 1.0412 - accuracy: 0.6613 - val_loss: 0.8169 - val_accuracy: 0.7375
# Epoch 17/50
# 375/375 [==============================] - 4s 11ms/step - loss: 1.0305 - accuracy: 0.6676 - val_loss: 0.8031 - val_accuracy: 0.7454
# Epoch 18/50
# 375/375 [==============================] - 5s 12ms/step - loss: 1.0011 - accuracy: 0.6764 - val_loss: 0.7706 - val_accuracy: 0.7531
# Epoch 19/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.9856 - accuracy: 0.6828 - val_loss: 0.7662 - val_accuracy: 0.7523
# Epoch 20/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.9726 - accuracy: 0.6875 - val_loss: 0.7444 - val_accuracy: 0.7679
# Epoch 21/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.9553 - accuracy: 0.6967 - val_loss: 0.7356 - val_accuracy: 0.7701
# Epoch 22/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.9333 - accuracy: 0.7031 - val_loss: 0.7261 - val_accuracy: 0.7763
# Epoch 23/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.9214 - accuracy: 0.7068 - val_loss: 0.7285 - val_accuracy: 0.7718
# Epoch 24/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.9067 - accuracy: 0.7135 - val_loss: 0.7139 - val_accuracy: 0.7828
# Epoch 25/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.8979 - accuracy: 0.7182 - val_loss: 0.6872 - val_accuracy: 0.7887
# Epoch 26/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.8741 - accuracy: 0.7268 - val_loss: 0.6812 - val_accuracy: 0.7877
# Epoch 27/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.8727 - accuracy: 0.7286 - val_loss: 0.6859 - val_accuracy: 0.7903
# Epoch 28/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.8590 - accuracy: 0.7328 - val_loss: 0.6551 - val_accuracy: 0.7995
# Epoch 29/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.8507 - accuracy: 0.7358 - val_loss: 0.6582 - val_accuracy: 0.7995
# Epoch 30/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.8407 - accuracy: 0.7396 - val_loss: 0.6606 - val_accuracy: 0.7985
# Epoch 31/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.8348 - accuracy: 0.7429 - val_loss: 0.6404 - val_accuracy: 0.8036
# Epoch 32/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.8159 - accuracy: 0.7487 - val_loss: 0.6403 - val_accuracy: 0.8062
# Epoch 33/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.8194 - accuracy: 0.7477 - val_loss: 0.6234 - val_accuracy: 0.8090
# Epoch 34/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.8085 - accuracy: 0.7517 - val_loss: 0.6346 - val_accuracy: 0.8028
# Epoch 35/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.7998 - accuracy: 0.7546 - val_loss: 0.6216 - val_accuracy: 0.8117
# Epoch 36/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.7964 - accuracy: 0.7580 - val_loss: 0.6182 - val_accuracy: 0.8145
# Epoch 37/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.7821 - accuracy: 0.7634 - val_loss: 0.6153 - val_accuracy: 0.8109
# Epoch 38/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.7831 - accuracy: 0.7626 - val_loss: 0.6053 - val_accuracy: 0.8143
# Epoch 39/50
# 375/375 [==============================] - 7s 17ms/step - loss: 0.7726 - accuracy: 0.7644 - val_loss: 0.6158 - val_accuracy: 0.8127
# Epoch 40/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.7628 - accuracy: 0.7671 - val_loss: 0.6046 - val_accuracy: 0.8173
# Epoch 41/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.7659 - accuracy: 0.7686 - val_loss: 0.5893 - val_accuracy: 0.8228
# Epoch 42/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.7651 - accuracy: 0.7691 - val_loss: 0.5990 - val_accuracy: 0.8201
# Epoch 43/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.7533 - accuracy: 0.7709 - val_loss: 0.6010 - val_accuracy: 0.8159
# Epoch 44/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.7497 - accuracy: 0.7735 - val_loss: 0.5868 - val_accuracy: 0.8207
# Epoch 45/50
# 375/375 [==============================] - 5s 15ms/step - loss: 0.7391 - accuracy: 0.7772 - val_loss: 0.5752 - val_accuracy: 0.8252
# Epoch 46/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.7456 - accuracy: 0.7754 - val_loss: 0.5881 - val_accuracy: 0.8183
# Epoch 47/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.7390 - accuracy: 0.7774 - val_loss: 0.5967 - val_accuracy: 0.8213
# Epoch 48/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.7343 - accuracy: 0.7806 - val_loss: 0.5793 - val_accuracy: 0.8238
# Epoch 49/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.7217 - accuracy: 0.7826 - val_loss: 0.5674 - val_accuracy: 0.8254
# Epoch 50/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.7158 - accuracy: 0.7845 - val_loss: 0.5675 - val_accuracy: 0.8296
# 313/313 [==============================] - 1s 3ms/step - loss: 54.1641 - accuracy: 0.7626
# Neural network accuracy: 76.26%

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model2.predict(test_images_flat)
y_pred_classes = np.argmax(y_pred,axis = 1)
y_pred_classes
# Out:
# 313/313 [==============================] - 1s 3ms/step
# array([7, 2, 1, ..., 4, 5, 6])

# %%
sns.heatmap(sklearn.metrics.confusion_matrix(test_labels, y_pred_classes, normalize="true"), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Apprentissage en couche convolutionnelle

# %%
optimizer = RMSprop(learning_rate=0.001)
model_cnn = Sequential()
model_cnn.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='normal', input_shape=(28, 28, 1)))
model_cnn.add(Dropout(.3))
model_cnn.add(MaxPooling2D((2, 2)))
model_cnn.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='normal', input_shape=(28, 28, 1)))
model_cnn.add(Dropout(.3))
model_cnn.add(MaxPooling2D((2, 2)))
model_cnn.add(Flatten())
model_cnn.add(Dense(32, activation='relu', kernel_initializer='normal'))
model_cnn.add(Dropout(.3))
model_cnn.add(Dense(10, activation='softmax'))
model_cnn.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)
model_cnn.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 26, 26, 32)        320
#
#  dropout_89 (Dropout)        (None, 26, 26, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 11, 11, 32)        9248
#
#  dropout_90 (Dropout)        (None, 11, 11, 32)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 800)               0
#
#  dense_105 (Dense)           (None, 32)                25632
#
#  dropout_91 (Dropout)        (None, 32)                0
#
#  dense_106 (Dense)           (None, 10)                330
#
# =================================================================
# Total params: 35,530
# Trainable params: 35,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_cnn.fit(train_images, train_labels_oh, validation_split = 0.2, epochs=20, batch_size=130, callbacks = [callback])
scores = model.evaluate(test_images_flat, test_labels_oh)
print("Neural network accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/30
# 370/370 [==============================] - 40s 104ms/step - loss: 1.8337 - accuracy: 0.3487 - val_loss: 1.5292 - val_accuracy: 0.5698
# Epoch 2/30
# 370/370 [==============================] - 39s 106ms/step - loss: 1.3450 - accuracy: 0.5349 - val_loss: 1.2341 - val_accuracy: 0.6887
# Epoch 3/30
# 370/370 [==============================] - 41s 110ms/step - loss: 1.1326 - accuracy: 0.6162 - val_loss: 0.9741 - val_accuracy: 0.7628
# Epoch 4/30
# 370/370 [==============================] - 39s 106ms/step - loss: 0.9833 - accuracy: 0.6742 - val_loss: 0.8669 - val_accuracy: 0.8068
# Epoch 5/30
# 370/370 [==============================] - 42s 113ms/step - loss: 0.8619 - accuracy: 0.7200 - val_loss: 0.7480 - val_accuracy: 0.8186
# Epoch 6/30
# 370/370 [==============================] - 40s 109ms/step - loss: 0.7678 - accuracy: 0.7517 - val_loss: 0.5949 - val_accuracy: 0.8654
# Epoch 7/30
# 370/370 [==============================] - 41s 110ms/step - loss: 0.7021 - accuracy: 0.7739 - val_loss: 0.5847 - val_accuracy: 0.8658
# Epoch 8/30
# 370/370 [==============================] - 40s 108ms/step - loss: 0.6586 - accuracy: 0.7899 - val_loss: 0.5194 - val_accuracy: 0.8863
# Epoch 9/30
# 370/370 [==============================] - 45s 121ms/step - loss: 0.6222 - accuracy: 0.8004 - val_loss: 0.4778 - val_accuracy: 0.8878
# Epoch 10/30
# 370/370 [==============================] - 43s 117ms/step - loss: 0.5930 - accuracy: 0.8123 - val_loss: 0.4710 - val_accuracy: 0.8777
# Epoch 11/30
# 370/370 [==============================] - 37s 101ms/step - loss: 0.5646 - accuracy: 0.8189 - val_loss: 0.4369 - val_accuracy: 0.8978
# Epoch 12/30
# 370/370 [==============================] - 37s 100ms/step - loss: 0.5465 - accuracy: 0.8245 - val_loss: 0.4066 - val_accuracy: 0.8942
# Epoch 13/30
# 370/370 [==============================] - 38s 103ms/step - loss: 0.5353 - accuracy: 0.8310 - val_loss: 0.4116 - val_accuracy: 0.8984
# Epoch 14/30
# 370/370 [==============================] - 40s 109ms/step - loss: 0.5208 - accuracy: 0.8327 - val_loss: 0.3865 - val_accuracy: 0.9092
# Epoch 15/30
# 370/370 [==============================] - 44s 118ms/step - loss: 0.5073 - accuracy: 0.8396 - val_loss: 0.3882 - val_accuracy: 0.9036
# Epoch 16/30
# 370/370 [==============================] - 44s 118ms/step - loss: 0.4962 - accuracy: 0.8448 - val_loss: 0.4046 - val_accuracy: 0.9013
# Epoch 17/30
# 370/370 [==============================] - 43s 115ms/step - loss: 0.4865 - accuracy: 0.8461 - val_loss: 0.3448 - val_accuracy: 0.9170
# Epoch 18/30
# 370/370 [==============================] - 42s 114ms/step - loss: 0.4824 - accuracy: 0.8481 - val_loss: 0.3444 - val_accuracy: 0.9057
# Epoch 19/30
# 370/370 [==============================] - 40s 108ms/step - loss: 0.4716 - accuracy: 0.8503 - val_loss: 0.3969 - val_accuracy: 0.8963
# Epoch 20/30
# 370/370 [==============================] - 40s 107ms/step - loss: 0.4655 - accuracy: 0.8530 - val_loss: 0.3709 - val_accuracy: 0.8950
# Epoch 21/30
# 370/370 [==============================] - 45s 122ms/step - loss: 0.4604 - accuracy: 0.8539 - val_loss: 0.3352 - val_accuracy: 0.9172
# Epoch 22/30
# 370/370 [==============================] - 42s 114ms/step - loss: 0.4575 - accuracy: 0.8566 - val_loss: 0.3336 - val_accuracy: 0.9198
# Epoch 23/30
# 370/370 [==============================] - 47s 127ms/step - loss: 0.4559 - accuracy: 0.8571 - val_loss: 0.3269 - val_accuracy: 0.9107
# Epoch 24/30
# 370/370 [==============================] - 36s 96ms/step - loss: 0.4485 - accuracy: 0.8607 - val_loss: 0.3201 - val_accuracy: 0.9153
# Epoch 25/30
# 370/370 [==============================] - 36s 97ms/step - loss: 0.4454 - accuracy: 0.8615 - val_loss: 0.3262 - val_accuracy: 0.9235
# Epoch 26/30
# 370/370 [==============================] - 35s 96ms/step - loss: 0.4468 - accuracy: 0.8625 - val_loss: 0.2635 - val_accuracy: 0.9260
# Epoch 27/30
# 370/370 [==============================] - 35s 96ms/step - loss: 0.4391 - accuracy: 0.8631 - val_loss: 0.3207 - val_accuracy: 0.9206
# Epoch 28/30
# 370/370 [==============================] - 35s 96ms/step - loss: 0.4450 - accuracy: 0.8608 - val_loss: 0.3329 - val_accuracy: 0.9107
# Epoch 29/30
# 370/370 [==============================] - 37s 100ms/step - loss: 0.4397 - accuracy: 0.8624 - val_loss: 0.3323 - val_accuracy: 0.9138
# Epoch 30/30
# 370/370 [==============================] - 36s 97ms/step - loss: 0.4277 - accuracy: 0.8657 - val_loss: 0.3029 - val_accuracy: 0.9197

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model_cnn.predict(test_images)
y_pred_classes = np.argmax(y_pred,axis = 1)
y_pred_classes
# Out:
# 313/313 [==============================] - 2s 6ms/step
# array([7, 2, 1, ..., 4, 3, 6])

# %%
sns.heatmap(sklearn.metrics.confusion_matrix(test_labels, y_pred_classes, normalize="true"), annot=True)
# Out:
# <Axes: >

# %%
optimizer = RMSprop(learning_rate=0.001)
model_cnn2 = Sequential()
model_cnn2.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='normal', input_shape=(28, 28, 1)))
model_cnn2.add(Dropout(.1))
model_cnn2.add(MaxPooling2D((2, 2)))
model_cnn2.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='normal', input_shape=(28, 28, 1)))
model_cnn2.add(Dropout(.1))
model_cnn2.add(Flatten())
model_cnn2.add(Dense(32, activation='relu', kernel_initializer='normal'))
model_cnn2.add(Dropout(.3))
model_cnn2.add(Dense(10, activation='softmax'))
model_cnn2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)
model_cnn2.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 26, 26, 32)        320
#
#  dropout_93 (Dropout)        (None, 26, 26, 32)        0
#
#  max_pooling2d_12 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 11, 11, 32)        9248
#
#  dropout_94 (Dropout)        (None, 11, 11, 32)        0
#
#  flatten_8 (Flatten)         (None, 3872)              0
#
#  dense_107 (Dense)           (None, 32)                123936
#
#  dropout_95 (Dropout)        (None, 32)                0
#
#  dense_108 (Dense)           (None, 10)                330
#
# =================================================================
# Total params: 133,834
# Trainable params: 133,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_cnn2.fit(train_images, train_labels_oh, validation_split = 0.2, epochs=20, batch_size=130, callbacks = [callback])
scores = model.evaluate(test_images_flat, test_labels_oh)
print("Neural network accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/20
# 370/370 [==============================] - 44s 116ms/step - loss: 1.7860 - accuracy: 0.3657 - val_loss: 1.2739 - val_accuracy: 0.5761
# Epoch 2/20
# 370/370 [==============================] - 36s 96ms/step - loss: 1.2478 - accuracy: 0.5719 - val_loss: 0.9769 - val_accuracy: 0.7072
# Epoch 3/20
# 370/370 [==============================] - 35s 94ms/step - loss: 1.0129 - accuracy: 0.6598 - val_loss: 0.7446 - val_accuracy: 0.7918
# Epoch 4/20
# 370/370 [==============================] - 35s 96ms/step - loss: 0.8521 - accuracy: 0.7191 - val_loss: 0.6647 - val_accuracy: 0.7955
# Epoch 5/20
# 370/370 [==============================] - 37s 100ms/step - loss: 0.7438 - accuracy: 0.7579 - val_loss: 0.6109 - val_accuracy: 0.8065
# Epoch 6/20
# 370/370 [==============================] - 37s 101ms/step - loss: 0.6650 - accuracy: 0.7843 - val_loss: 0.4348 - val_accuracy: 0.8829
# Epoch 7/20
# 370/370 [==============================] - 38s 102ms/step - loss: 0.6078 - accuracy: 0.8058 - val_loss: 0.4173 - val_accuracy: 0.8845
# Epoch 8/20
# 370/370 [==============================] - 39s 106ms/step - loss: 0.5629 - accuracy: 0.8210 - val_loss: 0.4208 - val_accuracy: 0.8737
# Epoch 9/20
# 370/370 [==============================] - 38s 103ms/step - loss: 0.5259 - accuracy: 0.8322 - val_loss: 0.3492 - val_accuracy: 0.9003
# Epoch 10/20
# 370/370 [==============================] - 41s 111ms/step - loss: 0.4988 - accuracy: 0.8413 - val_loss: 0.3277 - val_accuracy: 0.9104
# Epoch 11/20
# 370/370 [==============================] - 37s 101ms/step - loss: 0.4773 - accuracy: 0.8494 - val_loss: 0.3195 - val_accuracy: 0.9107
# Epoch 12/20
# 370/370 [==============================] - 34s 92ms/step - loss: 0.4573 - accuracy: 0.8555 - val_loss: 0.3743 - val_accuracy: 0.8937
# Epoch 13/20
# 370/370 [==============================] - 35s 95ms/step - loss: 0.4475 - accuracy: 0.8590 - val_loss: 0.4176 - val_accuracy: 0.8764
# Epoch 14/20
# 370/370 [==============================] - 37s 100ms/step - loss: 0.4346 - accuracy: 0.8628 - val_loss: 0.2996 - val_accuracy: 0.9096
# Epoch 15/20
# 370/370 [==============================] - 33s 89ms/step - loss: 0.4233 - accuracy: 0.8679 - val_loss: 0.3896 - val_accuracy: 0.8803
# Epoch 16/20
# 370/370 [==============================] - 33s 90ms/step - loss: 0.4085 - accuracy: 0.8717 - val_loss: 0.4585 - val_accuracy: 0.8485
# 313/313 [==============================] - 1s 2ms/step - loss: 80.0309 - accuracy: 0.7977
# Neural network accuracy: 79.77%

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model_cnn2.predict(test_images)
y_pred_classes = np.argmax(y_pred,axis = 1)
y_pred_classes
# Out:
# 313/313 [==============================] - 1s 4ms/step
# array([7, 2, 1, ..., 4, 4, 6])

# %%
sns.heatmap(sklearn.metrics.confusion_matrix(test_labels, y_pred_classes, normalize="true"), annot=True)
# Out:
# <Axes: >
